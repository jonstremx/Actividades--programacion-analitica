# %%
#ejercicio 1
def saludar():
    print("Hola")

saludar()
# Out:
# Hola

# %%
# ejercicio 2
def bienvenida():
    print("bienvenido al curso")

bienvenida()
# Out:
# bienvenido al curso

# %%
# ejericio 3
def uno():
    print("A")
print("B")
uno()
print("C")

#Se ejecuta primer B, D y despues C

# %%
#EJERICIO 4


def Saludar(nombre):
    print("Hola,", nombre)

Saludar("Ana")

# %%
# Ejericio 5
def Saludar(nombre):
    print("Hola,", nombre)
Saludar("Ana")

# %%
# ejericicio 6
def area(base,altura):
    return base*altura
print(area(3,4))

# %%
# ejericicio 7
def area(base,altura):
    return base*altura
print(area(5,5))

# %%
# ejericio 8
def con_iva(presio):
    return presio*1.19
print(con_iva(500))
print(con_iva(100))
print(con_iva(750))

# %%
# ejericio 9
def doble(n):
    return n*2
resultado = doble(5)
#es es el parametro por que es el nombre usado en la funcion
# y 5 el argumento por que es el valor real a definir en n

# %%
# ehericio 10
def perfil(nombre,edad,ciudad):
    print(nombre,edad,ciudad)
perfil("Ana",20,"Bogota")

# %%
# ejercicio 11
def perfil(nombre,edad,ciudad):
    print(nombre,edad,ciudad)
perfil(edad=20,nombre="Ana",ciudad="Bogota")

# %%
# ejercicio 12
def saludar(nombre,saludo="Hola"):
    print(saludo,nombre)
saludar("Ana,")

# %%
# ejercicio 13
def saludar(nombre, saludo="Buen dia"):
    print(saludo,nombre)

saludar("Luis", "Buen dia")

# %%
# ejericio 14
def registrar(producto,cantidad=1):
    print(producto, cantidad)

# %%
#Ejercicio 15
def total(precios):
    suma = 0
    for p in precios:
        suma = suma + p
    return suma
print(total([1200,950,3400]))

# %%
# ejericio 16
def doble(n):
    return n*2
print(doble(5))

# %%
# ejericio 17
def doble(n):
    return n*2
resultado =doble(6)
print(resultado +1)

# %%
def saludo(nombre):
    print("Hola,", nombre)
x = saludo("Ana")
print(x)

# %%
# ejericio 19
def doble(n):
    return(n*2)
total = doble(5) + 3
print(total)

# %%
# ejericio 20
def signo(n):
    if n < 0:
        return "Negativo"
    else: 
        return "Positivo"
print(signo(-4))
print(signo(7))

# %%
# Ejericio 21
def prueba(n):
    if n > 0:
        return "Positivo"
    print("linea intermedia")
    return "otro"
print(prueba(-1))

#no se ejecuta print("linea intermedia")

# %%
#ejericio 22
def resumen(valores):
    return min(valores), max(valores)

menor, mayor = resumen([8,3,10,5])
print(menor,mayor)

# %%
# ejericio 23
def con_iva(p):
    return p* 1019
def redondear(valor):
    return round(valor, 2)
print(redondear(con_iva(1200)))

# %%
# ejericio 24
mensaje = "global"
def prueba():
    mensaje = "local"
    print(mensaje)

prueba()
print(mensaje)

# %%
# ejericicio 25


def con_iva(precio):
    iva = 0.19
    return precio * (1 + iva)
con_iva(500)

# %%
# ejericio 26
def agregar(lista):
    nueva = lista +[3]
    return nueva
datos = [1,2]
print(agregar(datos))
print(datos)

# %%
# ejericio 27
def promedio(notas):
    total = 0
    for n in notas:
        total = total + n
    return total/len(notas)
print(promedio([3.5,4.2,2.8]))

# %%
# ejericio 28
def describir(alumno):
    print(alumno["nombre"],alumno["nota"])
describir({"nombre":"Laura","nota":4.6})

# %%
# ejercicio 29
def aprobados(estudiantes):
    resultado = []
    for e in estudiantes:
        if e["nota"] > 3.0:
            resultado.append(e["nombre"])
    return resultado
datos = [{"nombre":"Ana", "nota":4.2},
         {"nombre":"Luis", "nota":2.0}]
print(aprobados(datos))

# %%
# ejercicio 30
def promedio(notas):
 total = 0
 for n in notas:
    total = total + n
 return total / len(notas)
def aprueba(prom, minimo=3.5):
 return prom >= minimo
def reporte(nombre, notas):
 prom = promedio(notas)
 print(nombre, round(prom, 2))
 if aprueba(prom):
   print("Aprobado")
 else:
   print("No aprobado")
reporte("Laura", [3.5, 4.2, 2.8])
# Out:
# Laura 3.5
# Aprobado
